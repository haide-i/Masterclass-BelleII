# %% [markdown]
# # Import

# %%
# %matplotlib widget
import ipywidgets as widgets
import matplotlib.pyplot as plt
from src.particle import *
from src.tracker import *
from src.widgets import *
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Tracking

# %%
path = 'EEPiPi/fourparticles_00.h5'

# %%
tw = TrackingWidget(path, B = 0.1, )
tw.show()
# Out:
# Tab(children=(VBox(children=(FloatSlider(value=1e-05, description='radius', max=20.0), FloatSlider(value=0.0, …
# Output()
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# max_hit = {}
# for i in range(4):
#     max_hit[int(hits.iloc[i].idxmax())] = i

# %%
ew = ECLWidget(path, noise_rate = 0.0, )
ew.show()
