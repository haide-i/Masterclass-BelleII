# %% [markdown]
# # Interpretation von Ereignissen

# %% [markdown]
# <div class="alert alert-info">
# <strong>Aufgabe:</strong>
# Führe die untere Zelle aus, um die Aufgabe zu starten.

# %%
# %matplotlib widget
from src.widgets import *
import os
list_of_ls = os.popen("ls barrel").read().split('\n')[:-1]
import warnings
warnings.filterwarnings('ignore')
two_particle_event = "MuMuMuMu/fourparticles_00.h5"

# %% [markdown]
# ## Was ist ein Ereignis?

# %% [markdown]
# Ein Teilchendetektor sieht meistens nicht nur ein Teilchen nach dem anderen, sondern mehrere gleichzeitig. Nimmt ein Detektor also mehrere Teilchen gleichzeitig wahr, wird dass ein Ereigniss genannt. Was für Teilchen dabei auftreten ist unterschiedlich und unterliegt dem Zufall. Trotzdem gibt es bestimmte Muster, die für alle Teilchen gelten:
#  - *Energieerhaltung*: Die Summe der Energien am Anfang des Ereignisses ist gleich der Summe der Energien am Ende des Ereignis. Anders gesagt: Energie kann nicht einfach verschwinden.
#  - *Ladungserhaltung*: Die Summe der Ladungen am Anfang des Ereignisses ist gleich der Summe der Ladungen am Ende des Ereignis.

# %% [markdown]
# # Ein Ereignis mit zwei Teilchen

# %% [markdown]
# ## Reconstruieren zweier Teilchenspuren

# %% [markdown]
# Wir verwenden wieder den Detektor aus den vorherigen Aufgaben. Aber wir haben gleich zwei Teilchen gemessen. Damit müssen auch zwei Spuren rekonstruiert werden.

# %% [markdown]
# <div class="alert alert-info">
# <strong>Aufgabe:</strong>
#
# Rekonstruiere die Spuren der beiden Teilchen.

# %% [markdown]
# <div class="alert alert-warning">
# <strong>Hinweis:</strong>
#
# Mit hilfe der Tabs kannst du zwischen den verschiedenen Teilchen wechseln. Detektorteile, die bereits von anderen Teilchen getroffen werden, werden dann blass eingefärbt.

# %%
for p in list_of_ls:
    print(f"-------------{p}--------------")
    tw = TrackingWidget(f"barrel/{p}", noise = 0)
    tw.show()
# Out:
#   File "<ipython-input-1-292921c12868>", line 1
#     for p in list_of_ls
#                        ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Reconstruieren zweier Cluster

# %% [markdown]
# Auch im Kaloriemeter erwarten wir nun zwei Cluster die es zu selectieren gilt.

# %% [markdown]
# <div class="alert alert-info">
# <strong>Aufgabe:</strong>
#
# Rekonstruiere die Spuren der beiden Teilchen.

# %% [markdown]
# <div class="alert alert-warning">
# <strong>Hinweis:</strong>
#
# Um den Cluster für das nächste Teilchen auszuwählen, kannst du hier das Dropdown-Menu nutzen. Bereits ausgewählte Cluster werden als Erinnerung wieder blass eingefärbt.

# %%
for p in list_of_ls:
    print(f"-------------{p}--------------")
    ew = ECLWidget(f"barrel/{p}", noise_rate = 0)
    ew.show()
# Out:
# ...
# Output()
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
