# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib widget
from src.widgets import *
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
filepath = '/ceph/ihaide/GirlsDay/fourvectors/mixed/'

df1 = pd.read_hdf(filepath + f'fourparticles_1420_test.h5')
df1.iloc[0][df1.iloc[0]>0.0]
# Out:
# 2652             0.026214
# 2653             0.129936
# 2797             0.045971
# event            2.000000
# mass             0.105658
# energy           2.105225
# theta           65.954938
# phi            162.911872
# p                2.102572
# py               0.564213
# pz               0.856704
# pt               1.920122
# energy_diff      1.903105
# Name: 0, dtype: float64

# %%
i=142

two_particle_event = f"/ceph/ihaide/GirlsDay/fourvectors/mixed/fourparticles_1420_2test.h5"

ew = ECLWidget(two_particle_event, noise_rate = 0.0, idx=None)
ew.show()
# Out:
# ...
# Output()
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
two_particle_event = f"/ceph/ihaide/GirlsDay/fourvectors/mixed/fourparticles_1420.h5"

ew = ECLWidget(two_particle_event, noise_rate = 0.0, idx=None)
ew.show()
# Out:
# ...
# Output()
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
tw = TrackingWidget(two_particle_event, noise=0.0, show_truthbutton=True, n_segments=8, B=0.4)
tw.show()
# Out:
# ...
# Output()
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
